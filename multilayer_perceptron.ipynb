# %% [markdown]
# ## Multilayer Perceptron

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# dataset is loaded

# Normalize the images to [0, 1] range
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0   

print("Training data shape:", x_train.shape, y_train.shape)
# Out:
# Training data shape: (60000, 28, 28) (60000,)

# %%
fig, ax = plt.subplots(10, 10)
k = 0
for i in range(10):
    for j in range(10):
        ax[i][j].imshow(x_train[k].reshape(28, 28), aspect='auto')
        k += 1
plt.show()

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='sigmoid'),
    Dense(256, activation='sigmoid'),
    Dense(10, activation='softmax')
])
# Out:
# c:\Users\mural\OneDrive\Desktop\internship\tensorflowproj\tf_env\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

# %%
mod = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8829 - loss: 0.4099 - val_accuracy: 0.9441 - val_loss: 0.1977
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9465 - loss: 0.1733 - val_accuracy: 0.9596 - val_loss: 0.1397
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9650 - loss: 0.1174 - val_accuracy: 0.9607 - val_loss: 0.1279
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9740 - loss: 0.0856 - val_accuracy: 0.9704 - val_loss: 0.1042
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9807 - loss: 0.0643 - val_accuracy: 0.9720 - val_loss: 0.0920
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9846 - loss: 0.0487 - val_accuracy: 0.9746 - val_loss: 0.0891
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9887 - loss: 0.0364 - val_accuracy: 0.9763 - val_loss: 0.0847
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9914 - loss: 0.0278 - val_accuracy: 0.9722 - val_loss: 0.1033
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9932 - loss: 0.0213 - val_accuracy: 0.9730 - val_loss: 0.1045
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9939 - loss: 0.0179 - val_accuracy: 0.9760 - val_loss: 0.0936

# %%
result = model.evaluate(x_test, y_test)
print("Test Loss, Test Accuracy:", result)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9756 - loss: 0.0853
# Test Loss, Test Accuracy: [0.08529110997915268, 0.975600004196167]
